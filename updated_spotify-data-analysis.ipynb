# %%
# importing librearies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline
plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.1f}'.format)

# %% [markdown]
# ## Load dataset

# %%
df = pd.read_csv('D:\Projects\Musical-Analysis\spotify-2023.csv', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  in_apple_charts  \
# 0                147  141381703                  43              263
# 1                 48  133716286                  48              126
# 2                113  140003974                  94              207
# 3                100  800840817                 116              207
# 4                 50  303236322                  84              133
#
#   in_deezer_playlists  in_deezer_charts in_shazam_charts  bpm key   mode  \
# 0                  45                10              826  125   B  Major
# 1                  58                14              382   92  C#  Major
# 2                  91                14              949  138   F  Major
# 3                 125                12              548  170   A  Major
# 4                  87                15              425  144   A  Minor
#
#    danceability_%  valence_%  energy_%  acousticness_%  instrumentalness_%  \
# 0              80         89        83              31                   0
# 1              71         61        74               7                   0
# 2              51         32        53              17                   0
# 3              55         58        72              11                   0
# 4              65         23        80              14                  63
#
#    liveness_%  speechiness_%
# 0           8              4
# 1          10              4
# 2          31              6
# 3          11             15
# 4          11              6

# %%
#combine the columns into a single 'release_date' column
df['release_date'] = pd.to_datetime(df['released_year'].astype(str) + '-' +
                                    df['released_month'].astype(str) + '-' +
                                    df['released_day'].astype(str))

#drop the original year, month, and day columns
df.drop(columns=['released_year', 'released_month', 'released_day'], inplace=True)

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    in_spotify_playlists  in_spotify_charts    streams  in_apple_playlists  \
# 0                   553                147  141381703                  43
# 1                  1474                 48  133716286                  48
# 2                  1397                113  140003974                  94
# 3                  7858                100  800840817                 116
# 4                  3133                 50  303236322                  84
#
#    in_apple_charts in_deezer_playlists  in_deezer_charts in_shazam_charts  \
# 0              263                  45                10              826
# 1              126                  58                14              382
# 2              207                  91                14              949
# 3              207                 125                12              548
# 4              133                  87                15              425
#
#    bpm key   mode  danceability_%  valence_%  energy_%  acousticness_%  \
# 0  125   B  Major              80         89        83              31
# 1   92  C#  Major              71         61        74               7
# 2  138   F  Major              51         32        53              17
# 3  170   A  Major              55         58        72              11
# 4  144   A  Minor              65         23        80              14
#
#    instrumentalness_%  liveness_%  speechiness_% release_date
# 0                   0           8              4   2023-07-14
# 1                   0          10              4   2023-03-23
# 2                   0          31              6   2023-06-30
# 3                   0          11             15   2019-08-23
# 4                  63          11              6   2023-05-18

# %% [markdown]
# Another thing I discovered is there are columns that we are not gonna use or have benefit from them like the bpm (beats per minute), key and mode columns so we will drop them

# %%
df.drop(columns=['bpm', 'key', 'mode'], inplace=True)

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    in_spotify_playlists  in_spotify_charts    streams  in_apple_playlists  \
# 0                   553                147  141381703                  43
# 1                  1474                 48  133716286                  48
# 2                  1397                113  140003974                  94
# 3                  7858                100  800840817                 116
# 4                  3133                 50  303236322                  84
#
#    in_apple_charts in_deezer_playlists  in_deezer_charts in_shazam_charts  \
# 0              263                  45                10              826
# 1              126                  58                14              382
# 2              207                  91                14              949
# 3              207                 125                12              548
# 4              133                  87                15              425
#
#    danceability_%  valence_%  energy_%  acousticness_%  instrumentalness_%  \
# 0              80         89        83              31                   0
# 1              71         61        74               7                   0
# 2              51         32        53              17                   0
# 3              55         58        72              11                   0
# 4              65         23        80              14                  63
#
#    liveness_%  speechiness_% release_date
# 0           8              4   2023-07-14
# 1          10              4   2023-03-23
# 2          31              6   2023-06-30
# 3          11             15   2019-08-23
# 4          11              6   2023-05-18

# %%
df.shape
# Out:
# (953, 19)

# %%
df.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# release_date             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#check for duplicates in the 'track_name' column
df[df['track_name'].duplicated()]
# Out:
#                                  track_name  \
# 417                             Die For You
# 466  Let It Snow! Let It Snow! Let It Snow!
# 482                        SPIT IN MY FACE!
# 616                          Take My Breath
# 764                         About Damn Time
# 825                                 Flowers
# 831                                Daylight
# 852                                    Numb
# 873                                    SNAP
# 922                                Miss You
#
#                         artist(s)_name  artist_count  in_spotify_playlists  \
# 417                               Joji             1                  1703
# 466  Frank Sinatra, B. Swanson Quartet             2                 10585
# 482                           ThxSoMch             1                   573
# 616                         The Weeknd             1                  6392
# 764                              Lizzo             1                  9021
# 825               Lauren Spencer Smith             1                   801
# 831                       Harry Styles             1                  2775
# 852                 Marshmello, Khalid             2                  3879
# 873                          Rosa Linn             1                  1818
# 922                          Southstar             1                  2020
#
#      in_spotify_charts    streams  in_apple_playlists  in_apple_charts  \
# 417                  0  246390068                  38               45
# 466                  0  473248298                 126              108
# 482                  0  301869854                   1                0
# 616                  0  432702334                 174               73
# 764                  0  723894473                 242               49
# 825                  0  184826429                  42                9
# 831                  0  290833204                  21               11
# 852                  2  295307001                 107               76
# 873                  0  711366595                   3                0
# 922                  0  154356956                  77               10
#
#     in_deezer_playlists  in_deezer_charts in_shazam_charts  danceability_%  \
# 417                  36                16                0              47
# 466                 406                 0                0              60
# 482                  18                 0               24              70
# 616                 344                 0                0              75
# 764                 272                21               24              84
# 825                  24                 1                1              70
# 831                  40                 0                0              69
# 852                  86                 1                9              91
# 873                  63                 0              353              56
# 922                 119                 0               40              66
#
#      valence_%  energy_%  acousticness_%  instrumentalness_%  liveness_%  \
# 417         15        52              38                  13          29
# 466         86        32              88                   0          34
# 482         57        57               9                  20          11
# 616         53        74               2                   0          11
# 764         72        74              10                   0          34
# 825         31        44              84                   0           9
# 831         63        45              48                   0          18
# 852         63        77              12                   1          10
# 873         52        64              11                   0          45
# 922         24        58              17                   0          19
#
#      speechiness_% release_date
# 417              5   2022-11-04
# 466              6   1950-01-01
# 482              7   2022-10-31
# 616              5   2021-08-06
# 764              7   2022-04-14
# 825             39   2021-08-09
# 831              4   2022-05-20
# 852              5   2022-06-10
# 873              7   2022-03-19
# 922              5   1982-05-16

# %%
df = df.drop([574])
df['streams'] = pd.to_numeric(df['streams'])

# %%
# converting the streams column to numeric format
df['streams'] = pd.to_numeric(df['streams'])
df = df.sort_values(by='streams', ascending=False)

# %%
df = df.drop_duplicates(subset='track_name', keep='first')

# %%
#check for duplicates in the 'track_name' column
df[df['track_name'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [track_name, artist(s)_name, artist_count, in_spotify_playlists, in_spotify_charts, streams, in_apple_playlists, in_apple_charts, in_deezer_playlists, in_deezer_charts, in_shazam_charts, danceability_%, valence_%, energy_%, acousticness_%, instrumentalness_%, liveness_%, speechiness_%, release_date]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 942 entries, 55 to 123
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            942 non-null    object
#  1   artist(s)_name        942 non-null    object
#  2   artist_count          942 non-null    int64
#  3   in_spotify_playlists  942 non-null    int64
#  4   in_spotify_charts     942 non-null    int64
#  5   streams               942 non-null    int64
#  6   in_apple_playlists    942 non-null    int64
#  7   in_apple_charts       942 non-null    int64
#  8   in_deezer_playlists   942 non-null    object
#  9   in_deezer_charts      942 non-null    int64
#  10  in_shazam_charts      892 non-null    object
#  11  danceability_%        942 non-null    int64
#  12  valence_%             942 non-null    int64
#  13  energy_%              942 non-null    int64
#  14  acousticness_%        942 non-null    int64
#  15  instrumentalness_%    942 non-null    int64
#  16  liveness_%            942 non-null    int64
#  17  speechiness_%         942 non-null    int64
#  18  release_date          942 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(14), object(4)
# memory usage: 147.2+ KB

# %%
df.describe()
# Out:
#        artist_count  in_spotify_playlists  in_spotify_charts      streams  \
# count         942.0                 942.0              942.0        942.0
# mean            1.6                5231.2               12.1  515894838.7
# min             1.0                  31.0                0.0       2762.0
# 25%             1.0                 873.5                0.0  140668180.0
# 50%             1.0                2216.5                4.0  289165138.5
# 75%             2.0                5710.2               16.0  674004814.0
# max             8.0               52898.0              147.0 3703895074.0
# std             0.9                7936.6               19.6  569217397.6
#
#        in_apple_playlists  in_apple_charts  in_deezer_charts  danceability_%  \
# count               942.0            942.0             942.0           942.0
# mean                 68.2             52.3               2.7            67.0
# min                   0.0              0.0               0.0            23.0
# 25%                  13.0              7.0               0.0            57.0
# 50%                  34.0             39.0               0.0            69.0
# 75%                  88.0             87.0               2.0            78.0
# max                 672.0            275.0              58.0            96.0
# std                  86.8             50.7               6.0            14.6
#
#        valence_%  energy_%  acousticness_%  instrumentalness_%  liveness_%  \
# count      942.0     942.0           942.0               942.0       942.0
# mean        51.4      64.3            27.0                 1.6        18.2
# min          4.0       9.0             0.0                 0.0         3.0
# 25%         32.2      53.0             6.0                 0.0        10.0
# 50%         51.0      66.0            18.0                 0.0        12.0
# 75%         70.0      77.0            43.0                 0.0        23.0
# max         97.0      97.0            97.0                91.0        97.0
# std         23.5      16.5            25.9                 8.4        13.7
#
#        speechiness_%                   release_date
# count          942.0                            942
# mean            10.2  2018-10-24 18:35:55.414012928
# min              2.0            1930-01-01 00:00:00
# 25%              4.0            2020-07-02 18:00:00
# 50%              6.0            2022-04-08 00:00:00
# 75%             11.0            2022-11-04 00:00:00
# max             64.0            2023-07-14 00:00:00
# std              9.9                            NaN

# %%
df.drop(columns = ['in_shazam_charts'], inplace = True)

# %%
df.isnull().sum()
# Out:
# track_name              0
# artist(s)_name          0
# artist_count            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 0
# in_apple_playlists      0
# in_apple_charts         0
# in_deezer_playlists     0
# in_deezer_charts        0
# danceability_%          0
# valence_%               0
# energy_%                0
# acousticness_%          0
# instrumentalness_%      0
# liveness_%              0
# speechiness_%           0
# release_date            0
# dtype: int64

# %%
#remove commas from 'in_shazam_charts' column due to the above error
df['in_deezer_playlists'] = df['in_deezer_playlists'].str.replace(',', '')

#convert 'in_shazam_charts' column to numeric
df['in_deezer_playlists'] = pd.to_numeric(df['in_deezer_playlists'])

# %%
df.dtypes
# Out:
# track_name                      object
# artist(s)_name                  object
# artist_count                     int64
# in_spotify_playlists             int64
# in_spotify_charts                int64
# streams                          int64
# in_apple_playlists               int64
# in_apple_charts                  int64
# in_deezer_playlists              int64
# in_deezer_charts                 int64
# danceability_%                   int64
# valence_%                        int64
# energy_%                         int64
# acousticness_%                   int64
# instrumentalness_%               int64
# liveness_%                       int64
# speechiness_%                    int64
# release_date            datetime64[ns]
# dtype: object

# %% [markdown]
# ## Visualization

# %%
df
# Out:
#                                         track_name  \
# 55                                 Blinding Lights
# 179                                   Shape of You
# 86                               Someone You Loved
# 620                                   Dance Monkey
# 41   Sunflower - Spider-Man: Into the Spider-Verse
# ..                                             ...
# 68                                       Overdrive
# 142                    Gol Bolinha, Gol Quadrado 2
# 144                                          QUEMA
# 393                              Jhoome Jo Pathaan
# 123                                    Que Vuelvas
#
#                                         artist(s)_name  artist_count  \
# 55                                          The Weeknd             1
# 179                                         Ed Sheeran             1
# 86                                       Lewis Capaldi             1
# 620                                        Tones and I             1
# 41                               Post Malone, Swae Lee             2
# ..                                                 ...           ...
# 68                                         Post Malone             1
# 142                                Mc Pedrinho, DJ 900             2
# 144                       Sog, Ryan Castro, Peso Pluma             3
# 393  Arijit Singh, Vishal Dadlani, Sukriti Kakar, V...             6
# 123                         Carin Leon, Grupo Frontera             2
#
#      in_spotify_playlists  in_spotify_charts     streams  in_apple_playlists  \
# 55                  43899                 69  3703895074                 672
# 179                 32181                 10  3562543890                  33
# 86                  17836                 53  2887241814                 440
# 620                 24529                  0  2864791672                 533
# 41                  24094                 78  2808096550                 372
# ..                    ...                ...         ...                 ...
# 68                    410                 36    14780425                  36
# 142                   293                  8    11956641                   5
# 144                   437                 31    11599388                  17
# 393                   138                  4     1365184                  13
# 123                   763                 26        2762                  21
#
#      in_apple_charts  in_deezer_playlists  in_deezer_charts  danceability_%  \
# 55               199                 3421                20              50
# 179                0                 6808                 7              83
# 86               125                 1800                 0              50
# 620              167                 3595                 6              82
# 41               117                  843                 4              76
# ..               ...                  ...               ...             ...
# 68                32                   31                 1              56
# 142                2                   30                 2              93
# 144               29                   26                 3              79
# 393               78                    2                 0              82
# 123              110                   21                 9              49
#
#      valence_%  energy_%  acousticness_%  instrumentalness_%  liveness_%  \
# 55          38        80               0                   0           9
# 179         93        65              58                   0           9
# 86          45        41              75                   0          11
# 620         54        59              69                   0          18
# 41          91        50              54                   0           7
# ..         ...       ...             ...                 ...         ...
# 68          48        73               0                   0          35
# 142         68        65              42                   0          12
# 144         92        89               5                   0           6
# 393         62        74              10                   0          33
# 123         78        64              19                   0          11
#
#      speechiness_% release_date
# 55               7   2019-11-29
# 179              8   2017-01-06
# 86               3   2018-11-08
# 620             10   2019-05-10
# 41               5   2018-10-09
# ..             ...          ...
# 68               4   2023-07-14
# 142             25   2023-06-01
# 144              5   2023-07-13
# 393              7   2022-12-22
# 123              4   2022-12-09
#
# [942 rows x 18 columns]

# %% [markdown]
# ## Top 10 Artists having the most streamed songs in 2023

# %%
#count the number of songs released by each artist
artist_counts = df['artist(s)_name'].value_counts()

#select the top 10 artists
top_artists = artist_counts.head(10)

#the barplot represents Top 10 Artists Have Most Streamed Songs in 2023
plt.figure(figsize = (10, 6))

sns.barplot(x = top_artists.index, y = top_artists.values)

plt.title('Top 10 Artists Have Most Hits In 2023')
plt.xlabel('Artist')
plt.ylabel('Number of Hits')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Top 10 most Streamed songs in 2023

# %%
plt.figure(figsize = (20, 10))

sns.barplot(x = df.track_name[:10], y = df.streams)

plt.title('Top 10 Streamed Songs in 2023')
plt.xlabel('Artist')
plt.ylabel('Streams')
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Relationship Between The Number Of Artists In A Song and Streams In 2023

# %%
plt.figure(figsize = (20, 10))

sns.barplot(x = df.artist_count, y = df.streams)

plt.title('Relationship Between The Number Of Atrists In A Song and Streams In 2023')
plt.xlabel('Number of Artists')
plt.ylabel('Streams')
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Relationship Between Most Streamed Songs And Platforms In 2023

# %% [markdown]
# ### Spotify PLatform

# %%
plt.figure(figsize = (20, 10))

sns.regplot(x = 'streams', y = 'in_spotify_playlists', data = df, scatter = True, fit_reg = True)

plt.title('Relationship Between Most Streamed Songs And Spotify Playlists In 2023')
plt.xlabel('Streams')
plt.ylabel('Number of Spotify Playlists')
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Apple music

# %%
plt.figure(figsize = (20, 10))

sns.regplot(x = 'streams', y = 'in_apple_playlists', data = df, scatter = True, fit_reg = True)

plt.title('Relationship Between Most Streamed Songs And Apple Playlists In 2023')
plt.xlabel('Streams')
plt.ylabel('Number of Apple Playlists')
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Deezer Platform

# %%
plt.figure(figsize = (20, 10))

sns.regplot(x = 'streams', y = 'in_deezer_playlists', data = df, scatter = True, fit_reg = True)

plt.title('Relationship Between Most Streamed Songs And Deezer Playlists In 2023')
plt.xlabel('Streams')
plt.ylabel('Number of Deezer Playlists')
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Relationship Between All Audio Features

# %%
plt.figure(figsize = (12, 8))
corr = df[['danceability_%','valence_%', 'energy_%', 'acousticness_%', 'instrumentalness_%','liveness_%', 'speechiness_%']].corr()
sns.heatmap(corr, annot = True, cmap = 'coolwarm', vmin =- 1, vmax = 1)
plt.title('Correlation Heatmap of Audio Features')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Average Streams by Release Month

# %%
df['release_month'] = df['release_date'].dt.month
monthly_avg_streams = df.groupby('release_month')['streams'].mean()

plt.figure(figsize=(10, 6))
sns.barplot(x=monthly_avg_streams.index, y=monthly_avg_streams.values, palette='viridis')
plt.title('Average Streams by Release Month')
plt.xlabel('Month')
plt.ylabel('Average Streams')
#st.pyplot(plt)
# Out:
# Text(0, 0.5, 'Average Streams')

# %%
# Streams vs. Release Date
plt.figure(figsize=(12, 8))
sns.scatterplot(x='release_date', y='streams', data=df, hue='artist_count', palette='deep')
plt.title('Streams vs. Release Date')
plt.xlabel('Release Date')
plt.ylabel('Streams')
# Out:
# Text(0, 0.5, 'Streams')

# %%
# Correlation Between Audio Features and Streams
plt.figure(figsize=(12, 8))
audio_corr = df[['streams', 'danceability_%', 'valence_%', 'energy_%', 'acousticness_%', 
                 'instrumentalness_%', 'liveness_%', 'speechiness_%']].corr()
sns.heatmap(audio_corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Between Audio Features and Streams')
# Out:
# Text(0.5, 1.0, 'Correlation Between Audio Features and Streams')

# %%
print(df.columns)
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'danceability_%',
#        'valence_%', 'energy_%', 'acousticness_%', 'instrumentalness_%',
#        'liveness_%', 'speechiness_%', 'release_date', 'release_month'],
#       dtype='object')

# %%
# Set a colorful style
sns.set(style="whitegrid")

# Heatmap - Correlation Matrix
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

#  Violin Plot - Distribution of Streams across Danceability
plt.figure(figsize=(10, 6))

# %%
sns.violinplot(data=df, x="danceability_%", y="streams", palette="plasma")
plt.title("Streams Distribution across Danceability")
plt.show()

#  Pairplot - Exploring Multiple Relationships
sns.pairplot(df, vars=["danceability_%", "energy_%", "valence_%", "streams"], hue="artist_count", palette="coolwarm")
plt.show()

# Bubble Chart - Streams vs. BPM vs. Danceability (Bubble Size = Release Month)
plt.figure(figsize=(10, 6))
# sns.scatterplot(data=df, x="bpm", y="streams", size="danceability_%", hue="release_month", palette="viridis", sizes=(10, 300))
# plt.title("Bubble Chart: Streams vs. BPM vs. Danceability")

# %%
# 3D Scatter Plot - Energy vs. Valence vs. Acousticness
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df["energy_%"], df["valence_%"], df["acousticness_%"], c=df["streams"], cmap="plasma", s=50)
ax.set_xlabel("Energy (%)")
ax.set_ylabel("Valence (%)")
ax.set_zlabel("Acousticness (%)")
ax.set_title("3D Scatter: Energy vs. Valence vs. Acousticness")

plt.show()

# %%
# Scatter Plot: Streams vs. Danceability (Bubble Size = Energy)
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="danceability_%", y="streams", size="energy_%", hue="release_month", palette="coolwarm", sizes=(10, 300))
plt.title("Streams vs. Danceability vs. Energy")
plt.show()

# %%
# Heatmap for Correlation
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
#  Violin Plot: Distribution of Streams across Danceability
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x="danceability_%", y="streams", palette="plasma")
plt.title("Streams Distribution across Danceability")
plt.show()

# %%
# alette="coolwarm", sizes=(10, 300))
# plt.title("Streams vs. Danceability vs. Energy")
# plt.show()

# 2. Heatmap for Correlation
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
#  Violin Plot: Distribution of Streams across Danceability
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x="danceability_%", y="streams", palette="plasma")
plt.title("Streams Distribution across Danceability")
plt.show()
